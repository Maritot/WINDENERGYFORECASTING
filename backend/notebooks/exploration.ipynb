# %% [markdown]
# # Wind Energy Forecasting Exploration
#
# Use this notebook to inspect the dataset, understand feature distributions, and review training outputs after running the project scripts.

# %%
import pandas as pd

data = pd.read_csv('../data/wind.csv')
data.head()
